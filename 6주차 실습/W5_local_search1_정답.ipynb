# %% [markdown]
# ## 배낭 (Knapsack) 문제

# %% [markdown]
# - 가방(Knapsack)에 물건을 여러 개 담을 때 가방에 담은 물건들의 조합의 가치를 극대화 할 수 있는 방법을 찾는 문제
# - 다만, 배낭의 허용 용량을 초과하여 아이템을 담을 수 없다는 제약이 있음

# %%
import random
import math

class Knapsack:
    def __init__(self, items, capacity):
        self.items = items
        self.capacity = capacity

    def calculate_value(self, solution): # 총 가치 계산
        total_value = 0
        for i in range(len(self.items)):
            if solution[i] == 1:
                _, value, _ = self.items[i]
                total_value += value
        return total_value

    def measure_weight(self, solution): # 무게 측정
        total_weight = 0
        for i in range(len(self.items)):
            if solution[i] == 1:
                _, _, weight = self.items[i]
                total_weight += weight
        return total_weight

    def get_neighbors(self, solution):
        all_neighbors = []
        valid_neighbors = []
        for i in range(len(self.items)):
            neighbor = solution[:]
            neighbor[i] = 1 - neighbor[i]  # 물건 포함 여부를 뒤집음 (0 혹은 1)
            all_neighbors.append(neighbor)
        valid_neighbors = [n for n in all_neighbors if self.is_valid(n)]  # 무게 초과하지 않는 이웃 상태만 도출
        return valid_neighbors

    def is_valid(self, solution): 
        return self.measure_weight(solution) <= self.capacity # 아이템 총합 배낭 허용 용량 초과 여부 확인

    def random_initial_solution(self): # 초기 해 랜덤 생성
        while True:
            initial_solution = [random.randint(0, 1) for _ in range(len(self.items))]
            if self.is_valid(initial_solution):
                return initial_solution

# %%
# (이름, 가치, 무게) 튜플로 이루어진 아이템 목록
items = [
    ("책", 30, 1),
    ("노트북", 300, 3),
    ("물병", 20, 1),
    ("필통", 10, 1),
    ("간식", 50, 1),
    ("이어폰", 60, 0.5),
    ("공책", 15, 0.5),
    ("전공책", 100, 2)
]

# 배낭 용량
capacity = 5

# %% [markdown]
# ## 언덕 오르기 알고리즘

# %% [markdown]
# ```java
# Function HILL_CLIMBING(problem)
#   current_solution ← problem.initial_solution
#   while True
#     next_solution ← current_solution의 이웃 상태 중 가장 높은 값을 가진 상태
#     if next_solution의 값 > current_solution의 값
#       current_solution ← next_solution
#   return current_solution
# ```

# %%
import random

def hill_climbing(knapsack):
    # 초기 해 설정
    current_solution = knapsack.random_initial_solution()
    current_value = knapsack.calculate_value(current_solution)
    # print(f"초기값: {current_value}")
    # count = 1

    while True:
        # 현재 해의 이웃 상태들 계산
        neighbors = knapsack.get_neighbors(current_solution)
        # print(f"{count}번째 이웃상태: {[knapsack.calculate_value(n) for n in neighbors]}")

        # 이웃 중에서 가장 좋은 해 선택
        next_solution = None
        for neighbor in neighbors:
            neighbor_value = knapsack.calculate_value(neighbor)
            if neighbor_value > current_value:
                current_value = neighbor_value
                next_solution = neighbor

        # 반복을 다 돌고 난 이후에도 더 나은 해가 없으면 종료
        if next_solution is None:
            break
        
        # 더 나은 해로 이동
        current_solution = next_solution
        # count += 1

    # 최종 해와 그 가치를 반환
    return current_solution, current_value

# %%
initial_state = Knapsack(items, capacity)
solution, total_value = hill_climbing(initial_state)

# 결과 출력
selected_items = [items[i][0] for i in range(len(items)) if solution[i] == 1]
print(f"결과값: {total_value}, 아이템 목록: {solution}(={selected_items})")
# Out:
# 초기값: 220
# 1번째 이웃상태: [210, 170, 160, 235, 120]
# 2번째 이웃상태: [225, 185, 175, 220, 135]
# 결과값: 235, 아이템 목록: [0, 0, 0, 1, 1, 1, 1, 1](=['필통', '간식', '이어폰', '공책', '전공책'])

# %% [markdown]
# ## 무작위 재시작 언덕 오르기
# - 지역 최댓값을 피하기 위해 무작위로 재시작하는 언덕오르기 반복해 전역 최댓값 도출

# %%
solutions = []
for i in range(100):
    initial_state = Knapsack(items, capacity)
    solution, total_value = hill_climbing(initial_state)
    print(f'{i+1}번: {solution}, {total_value}')
    solutions.append((solution, total_value))

final_solution = max(results, key = lambda x:x[1])
final_items = [items[i][0] for i in range(len(items)) if final_solution[0][i] == 1]
print(f'최종목록: {final_items}, 최종값: {final_solution[1]}')
# Out:
# 1번: [0, 1, 1, 0, 1, 0, 0, 0], 370
# 2번: [0, 1, 0, 0, 1, 1, 1, 0], 425
# 3번: [1, 1, 0, 0, 0, 1, 1, 0], 405
# 4번: [1, 0, 1, 1, 0, 0, 0, 1], 160
# 5번: [1, 1, 0, 0, 0, 1, 1, 0], 405
# 6번: [0, 1, 0, 0, 0, 0, 0, 1], 400
# 7번: [0, 0, 0, 1, 1, 1, 1, 1], 235
# 8번: [0, 1, 1, 0, 1, 0, 0, 0], 370
# 9번: [0, 1, 1, 0, 0, 1, 1, 0], 395
# 10번: [1, 0, 0, 1, 1, 0, 0, 1], 190
# 11번: [1, 0, 1, 0, 0, 1, 1, 1], 225
# 12번: [1, 0, 1, 0, 0, 1, 1, 1], 225
# 13번: [0, 0, 0, 1, 1, 1, 1, 1], 235
# 14번: [0, 1, 0, 0, 0, 0, 0, 1], 400
# 15번: [0, 1, 0, 0, 1, 1, 1, 0], 425
# 16번: [0, 1, 0, 1, 0, 1, 1, 0], 385
# 17번: [0, 1, 0, 0, 1, 1, 1, 0], 425
# 18번: [0, 1, 0, 0, 1, 1, 1, 0], 425
# 19번: [1, 1, 0, 0, 0, 1, 1, 0], 405
# 20번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 21번: [0, 0, 1, 0, 1, 1, 1, 1], 245
# 22번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 23번: [1, 0, 0, 1, 1, 0, 0, 1], 190
# 24번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 25번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 26번: [0, 1, 0, 1, 0, 1, 1, 0], 385
# 27번: [1, 1, 0, 0, 0, 1, 1, 0], 405
# 28번: [1, 0, 0, 1, 0, 1, 1, 1], 215
# 29번: [0, 1, 1, 0, 0, 1, 1, 0], 395
# 30번: [1, 0, 0, 1, 1, 0, 0, 1], 190
# 31번: [1, 1, 0, 1, 0, 0, 0, 0], 340
# 32번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 33번: [0, 0, 1, 1, 0, 1, 1, 1], 205
# 34번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 35번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 36번: [1, 1, 0, 0, 1, 0, 0, 0], 380
# 37번: [0, 0, 1, 0, 1, 1, 1, 1], 245
# 38번: [1, 1, 0, 0, 0, 1, 1, 0], 405
# 39번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 40번: [0, 1, 0, 1, 0, 1, 1, 0], 385
# 41번: [0, 1, 0, 0, 1, 1, 1, 0], 425
# 42번: [0, 1, 0, 0, 1, 1, 1, 0], 425
# 43번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 44번: [0, 0, 0, 1, 1, 1, 1, 1], 235
# 45번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 46번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 47번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 48번: [0, 1, 1, 0, 0, 1, 1, 0], 395
# 49번: [0, 1, 0, 0, 1, 1, 1, 0], 425
# 50번: [0, 1, 1, 0, 0, 1, 1, 0], 395
# 51번: [0, 1, 0, 1, 1, 0, 0, 0], 360
# 52번: [0, 1, 0, 0, 1, 1, 1, 0], 425
# 53번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 54번: [1, 0, 0, 1, 0, 1, 1, 1], 215
# 55번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 56번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 57번: [0, 0, 1, 0, 1, 1, 1, 1], 245
# 58번: [0, 0, 0, 1, 1, 1, 1, 1], 235
# 59번: [1, 0, 1, 0, 0, 1, 1, 1], 225
# 60번: [1, 1, 0, 0, 0, 1, 1, 0], 405
# 61번: [0, 1, 0, 0, 1, 1, 1, 0], 425
# 62번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 63번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 64번: [0, 0, 1, 0, 1, 1, 1, 1], 245
# 65번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 66번: [1, 1, 0, 0, 0, 1, 1, 0], 405
# 67번: [1, 1, 0, 0, 0, 1, 1, 0], 405
# 68번: [0, 1, 0, 1, 1, 0, 0, 0], 360
# 69번: [1, 1, 0, 0, 0, 1, 1, 0], 405
# 70번: [1, 0, 1, 0, 0, 1, 1, 1], 225
# 71번: [1, 0, 1, 1, 0, 0, 0, 1], 160
# 72번: [1, 0, 0, 1, 0, 1, 1, 1], 215
# 73번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 74번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 75번: [1, 1, 0, 0, 0, 1, 1, 0], 405
# 76번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 77번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 78번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 79번: [0, 1, 1, 1, 0, 0, 0, 0], 330
# 80번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 81번: [0, 1, 0, 1, 0, 1, 1, 0], 385
# 82번: [0, 1, 0, 1, 0, 1, 1, 0], 385
# 83번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 84번: [0, 0, 1, 0, 1, 1, 1, 1], 245
# 85번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 86번: [1, 1, 0, 0, 0, 1, 1, 0], 405
# 87번: [1, 0, 0, 1, 0, 1, 1, 1], 215
# 88번: [0, 0, 0, 1, 1, 1, 1, 1], 235
# 89번: [0, 1, 0, 1, 1, 0, 0, 0], 360
# 90번: [1, 0, 1, 0, 0, 1, 1, 1], 225
# 91번: [0, 0, 1, 1, 0, 1, 1, 1], 205
# 92번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 93번: [1, 0, 0, 0, 1, 1, 1, 1], 255
# 94번: [0, 1, 0, 0, 0, 0, 0, 1], 400
# 95번: [1, 0, 0, 1, 0, 1, 1, 1], 215
# 96번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 97번: [0, 1, 0, 0, 1, 1, 1, 0], 425
# 98번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 99번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 100번: [1, 0, 1, 1, 1, 1, 1, 0], 185
# 최종목록: ['노트북', '간식', '이어폰', '공책'], 최종값: 425

# %% [markdown]
# ## 모의 정련(simulated annealing)

# %% [markdown]
# ```java
# Function SIMULATED_ANNEALING(problem)
#   current_solution ← problem.initial_solution
#   t ← 0
#   while True
#     T ← schedule(t)
#     if T = 0
#       return current_solution
#     next_state ← current_solution의 이웃 상태 중 무작위 선택
#     ΔE ← next_solution의 값 - current_solution의 값
#     if ΔE > 0
#       current_solution ← next_solution
#     else
#       current_solution ← next_solution #단, e^(ΔE/T)의 확률로!
#     t += 1
#   return current_solution
# ```
#
# - 단, schedule의 경우 냉각 스케쥴링(t가 늘어남에 따라 온도를 어떻게 감소시킬지 결정) 함수 추가 필요 (본 수업에서는 cooling_rate을 도입하여, 시간이 지남에 따라 온도가 선형적으로 감소하도록 만들 계획)

# %%
def cooling_schedule(t, initial_temp, cooling_rate): 
    temp = initial_temp - cooling_rate * t #선형 감소 
    if temp < 0:
        temp = 0
    return temp

# Simulated Annealing 알고리즘 구현 (출력 포함)
def simulated_annealing(problem, initial_temp=1000, cooling_rate=1.0):
    current_solution = problem.random_initial_solution()
    current_value = problem.calculate_value(current_solution)
    print(f"초기값: {current_value}")
    
    t = 0
    while True:
        # 선형 감소 방식으로 온도 계산
        temp = cooling_schedule(t, initial_temp, cooling_rate)
        
        # 온도가 0이면 종료, 온도는 0 이하로 내려가면안됨
        if temp == 0:
            break
        
        neighbors = problem.get_neighbors(current_solution)
        # print(f"{t+1}번째 이웃상태: {[problem.calculate_value(n) for n in neighbors]}, 현재값: {current_value}")
        
        next_solution = random.choice(neighbors) # 현재 해의 이웃 중 무작위 선택
        next_value = problem.calculate_value(next_solution)

        # ΔE 계산
        delta_E = next_value - current_value

        if delta_E > 0: # 더 좋은 해로 이동
            current_solution = next_solution
            current_value = next_value
        else:
            if random.random() < math.exp(delta_E / temp): # random.random() 은 0과 1 사이 실수 반환. 나쁜 해로 이동할 확률 무작위 선택. 
                # 결국 T가 낮아질수록 e^E/T 는 확률이 낮아짐 0에 가까워짐 = 무작위로 나쁜해 받아들일 확률 낮아져감
                current_solution = next_solution
                current_value = next_value

        t += 1  # 반복 횟수 증가

    # 최종 해와 그 가치를 반환
    return current_solution, current_value

# %%
initial_state = Knapsack(items, capacity)
solution, total_value = simulated_annealing(initial_state)

# 결과 출력
selected_items = [items[i][0] for i in range(len(items)) if solution[i] == 1]
print(f"결과값: {total_value}, 아이템 목록: {solution}(={selected_items})")
# Out:
# 초기값: 140
# 1번째 이웃상태: [110, 160, 150, 90, 80, 155, 240], 현재값: 140
# 2번째 이웃상태: [125, 175, 165, 105, 95, 140, 255], 현재값: 155
# 3번째 이웃상태: [65, 115, 105, 45, 155, 80, 195], 현재값: 95
# 4번째 이웃상태: [75, 125, 95, 55, 165, 90], 현재값: 105
# 5번째 이웃상태: [135, 185, 155, 115, 105, 150], 현재값: 165
# 6번째 이웃상태: [85, 135, 105, 165, 55, 100, 215], 현재값: 115
# 7번째 이웃상태: [75, 405, 125, 115, 155, 45, 90, 205], 현재값: 105
# 8번째 이웃상태: [15, 345, 65, 55, 95, 105, 30, 145], 현재값: 45
# 9번째 이웃상태: [65, 115, 105, 45, 155, 80, 195], 현재값: 95
# 10번째 이웃상태: [15, 345, 65, 55, 95, 105, 30, 145], 현재값: 45
# 11번째 이웃상태: [115, 165, 155, 195, 205, 130, 45], 현재값: 145
# 12번째 이웃상태: [135, 145, 225, 150, 65], 현재값: 165
# 13번째 이웃상태: [195, 205, 165, 210, 125], 현재값: 225
# 14번째 이웃상태: [225, 175, 205, 245, 135, 180, 95], 현재값: 195
# 15번째 이웃상태: [210, 160, 190, 230, 120, 195, 80], 현재값: 180
# 16번째 이웃상태: [170, 180, 130, 205, 90], 현재값: 190
# 17번째 이웃상태: [200, 190, 160, 220, 110, 185, 70], 현재값: 170
# 18번째 이웃상태: [190, 180, 170, 210, 100, 175, 60], 현재값: 160
# 19번째 이웃상태: [130, 400, 120, 110, 150, 160, 115, 0], 현재값: 100
# 20번째 이웃상태: [100, 300], 현재값: 400
# 21번째 이웃상태: [330, 0, 320, 310, 350, 360, 315, 400], 현재값: 300
# 22번째 이웃상태: [100, 300], 현재값: 400
# 23번째 이웃상태: [330, 0, 320, 310, 350, 360, 315, 400], 현재값: 300
# 24번째 이웃상태: [30, 300, 20, 10, 50, 60, 15, 100], 현재값: 0
# 25번째 이웃상태: [50, 320, 0, 30, 70, 80, 35, 120], 현재값: 20
# 26번째 이웃상태: [110, 380, 60, 90, 130, 20, 95, 180], 현재값: 80
# 27번째 이웃상태: [160, 110, 140, 80, 70, 145, 230], 현재값: 130
# 28번째 이웃상태: [140, 410, 130, 120, 60, 50, 125, 210], 현재값: 110
# 29번째 이웃상태: [155, 425, 145, 135, 75, 65, 110, 225], 현재값: 125
# 30번째 이웃상태: [105, 375, 95, 85, 125, 15, 60, 175], 현재값: 75
# 31번째 이웃상태: [45, 315, 35, 25, 65, 75, 0, 115], 현재값: 15
# 32번째 이웃상태: [55, 325, 45, 15, 75, 85, 10, 125], 현재값: 25
# 33번째 이웃상태: [75, 25, 35, 95, 105, 30, 145], 현재값: 45
# 34번째 이웃상태: [125, 135, 205, 130, 45], 현재값: 145
# 35번째 이웃상태: [155, 145, 115, 175, 185, 110, 25], 현재값: 125
# 36번째 이웃상태: [165, 125, 235, 160, 75], 현재값: 175
# 37번째 이웃상태: [225, 185, 175, 220, 135], 현재값: 235
# 38번째 이웃상태: [210, 170, 160, 235, 120], 현재값: 220
# 39번째 이웃상태: [200, 190, 160, 220, 110, 185, 70], 현재값: 170
# 40번째 이웃상태: [215, 205, 175, 235, 125, 170, 85], 현재값: 185
# 41번째 이웃상태: [185, 205, 155, 200, 115], 현재값: 215
# 42번째 이웃상태: [215, 205, 175, 235, 125, 170, 85], 현재값: 185
# 43번째 이웃상태: [115, 385, 105, 75, 135, 25, 70, 185], 현재값: 85
# 44번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 45번째 이웃상태: [70, 360, 310, 385], 현재값: 370
# 46번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 47번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 48번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 49번째 이웃상태: [320, 50, 330], 현재값: 350
# 50번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 51번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 52번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 53번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 54번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 55번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 56번째 이웃상태: [90, 360, 80, 70, 110, 0, 75, 160], 현재값: 60
# 57번째 이웃상태: [60, 390, 110, 100, 140, 30, 105, 190], 현재값: 90
# 58번째 이웃상태: [0, 330, 50, 40, 80, 90, 45, 130], 현재값: 30
# 59번째 이웃상태: [15, 345, 65, 55, 95, 105, 30, 145], 현재값: 45
# 60번째 이웃상태: [65, 115, 105, 45, 155, 80, 195], 현재값: 95
# 61번째 이웃상태: [15, 345, 65, 55, 95, 105, 30, 145], 현재값: 45
# 62번째 이웃상태: [35, 45, 75, 115, 125, 50, 165], 현재값: 65
# 63번째 이웃상태: [135, 145, 225, 150, 65], 현재값: 165
# 64번째 이웃상태: [165, 115, 145, 185, 195, 120, 35], 현재값: 135
# 65번째 이웃상태: [65, 335, 15, 45, 85, 95, 20, 135], 현재값: 35
# 66번째 이웃상태: [125, 395, 75, 105, 145, 35, 80, 195], 현재값: 95
# 67번째 이웃상태: [175, 125, 155, 95, 85, 130, 245], 현재값: 145
# 68번째 이웃상태: [115, 65, 95, 35, 145, 70, 185], 현재값: 85
# 69번째 이웃상태: [165, 135, 245, 170, 85], 현재값: 185
# 70번째 이웃상태: [165, 115, 145, 185, 195, 120, 35], 현재값: 135
# 71번째 이웃상태: [165, 135, 245, 170, 85], 현재값: 185
# 72번째 이웃상태: [200, 150, 180, 120, 230, 185, 70], 현재값: 170
# 73번째 이웃상태: [160, 170, 130, 80], 현재값: 180
# 74번째 이웃상태: [200, 150, 180, 120, 230, 185, 70], 현재값: 170
# 75번째 이웃상태: [180, 170, 160, 100, 210, 165, 50], 현재값: 150
# 76번째 이웃상태: [80, 350, 70, 60, 0, 110, 65, 150], 현재값: 50
# 77번째 이웃상태: [100, 370, 50, 80, 20, 130, 85, 170], 현재값: 70
# 78번째 이웃상태: [110, 60, 70, 30, 140, 95, 180], 현재값: 80
# 79번째 이웃상태: [80, 90, 100, 60, 170, 125], 현재값: 110
# 80번째 이웃상태: [95, 105, 115, 75, 185, 110], 현재값: 125
# 81번째 이웃상태: [155, 165, 175, 135, 125, 170], 현재값: 185
# 82번째 이웃상태: [145, 155, 185, 125, 115, 160], 현재값: 175
# 83번째 이웃상태: [125, 175, 165, 105, 95, 140, 255], 현재값: 155
# 84번째 이웃상태: [145, 155, 185, 125, 115, 160], 현재값: 175
# 85번째 이웃상태: [85, 95, 125, 65, 175, 100], 현재값: 115
# 86번째 이웃상태: [115, 65, 95, 35, 145, 70, 185], 현재값: 85
# 87번째 이웃상태: [65, 335, 15, 45, 85, 95, 20, 135], 현재값: 35
# 88번째 이웃상태: [115, 65, 95, 35, 145, 70, 185], 현재값: 85
# 89번째 이웃상태: [95, 365, 85, 75, 15, 125, 50, 165], 현재값: 65
# 90번째 이웃상태: [195, 185, 175, 115, 225, 150, 65], 현재값: 165
# 91번째 이웃상태: [165, 135, 245, 170, 85], 현재값: 185
# 92번째 이웃상태: [165, 135, 245, 170, 85], 현재값: 185
# 93번째 이웃상태: [200, 150, 180, 120, 230, 185, 70], 현재값: 170
# 94번째 이웃상태: [170, 180, 150, 100], 현재값: 200
# 95번째 이웃상태: [150, 200, 190, 130, 240, 195, 80], 현재값: 180
# 96번째 이웃상태: [150, 200, 190, 130, 240, 195, 80], 현재값: 180
# 97번째 이웃상태: [210, 190, 180, 255, 140], 현재값: 240
# 98번째 이웃상태: [150, 200, 190, 130, 240, 195, 80], 현재값: 180
# 99번째 이웃상태: [100, 150, 140, 180, 190, 145, 30], 현재값: 130
# 100번째 이웃상태: [160, 210, 200, 240, 130, 205, 90], 현재값: 190
# 101번째 이웃상태: [175, 225, 215, 255, 145, 190, 105], 현재값: 205
# 102번째 이웃상태: [205, 195, 185, 225, 115, 160, 75], 현재값: 175
# 103번째 이웃상태: [255, 245, 235, 175, 165, 210, 125], 현재값: 225
# 104번째 이웃상태: [195, 185, 175, 115, 225, 150, 65], 현재값: 165
# 105번째 이웃상태: [165, 135, 245, 170, 85], 현재값: 185
# 106번째 이웃상태: [200, 150, 180, 120, 230, 185, 70], 현재값: 170
# 107번째 이웃상태: [170, 180, 150, 100], 현재값: 200
# 108번째 이웃상태: [120, 130, 160, 200, 210, 165, 50], 현재값: 150
# 109번째 이웃상태: [130, 140, 150, 60], 현재값: 160
# 110번째 이웃상태: [160, 110, 120, 180, 190, 145, 30], 현재값: 130
# 111번째 이웃상태: [130, 140, 150, 60], 현재값: 160
# 112번째 이웃상태: [160, 110, 120, 180, 190, 145, 30], 현재값: 130
# 113번째 이웃상태: [125, 135, 205, 130, 45], 현재값: 145
# 114번째 이웃상태: [75, 25, 35, 95, 105, 30, 145], 현재값: 45
# 115번째 이웃상태: [65, 335, 15, 45, 85, 95, 20, 135], 현재값: 35
# 116번째 이웃상태: [35, 45, 75, 115, 125, 50, 165], 현재값: 65
# 117번째 이웃상태: [20, 350, 30, 60, 100, 110, 65, 150], 현재값: 50
# 118번째 이웃상태: [70, 80, 110, 50, 160, 115, 200], 현재값: 100
# 119번째 이웃상태: [100, 370, 50, 80, 20, 130, 85, 170], 현재값: 70
# 120번째 이웃상태: [115, 65, 95, 35, 145, 70, 185], 현재값: 85
# 121번째 이웃상태: [125, 75, 85, 45, 155, 80], 현재값: 95
# 122번째 이웃상태: [95, 105, 115, 75, 185, 110], 현재값: 125
# 123번째 이웃상태: [85, 95, 125, 65, 175, 100], 현재값: 115
# 124번째 이웃상태: [35, 45, 75, 115, 125, 50, 165], 현재값: 65
# 125번째 이웃상태: [45, 55, 65, 125, 135, 60], 현재값: 75
# 126번째 이웃상태: [105, 115, 125, 185, 75, 120], 현재값: 135
# 127번째 이웃상태: [135, 85, 95, 155, 45, 90, 205], 현재값: 105
# 128번째 이웃상태: [185, 135, 145, 105, 95, 140], 현재값: 155
# 129번째 이웃상태: [155, 165, 175, 135, 125, 170], 현재값: 185
# 130번째 이웃상태: [105, 115, 125, 185, 75, 120], 현재값: 135
# 131번째 이웃상태: [90, 100, 110, 170, 60, 135], 현재값: 120
# 132번째 이웃상태: [140, 150, 160, 120, 110, 185], 현재값: 170
# 133번째 이웃상태: [80, 90, 100, 60, 170, 125], 현재값: 110
# 134번째 이웃상태: [110, 60, 70, 30, 140, 95, 180], 현재값: 80
# 135번째 이웃상태: [60, 330, 10, 20, 80, 90, 45, 130], 현재값: 30
# 136번째 이웃상태: [120, 70, 80, 140, 30, 105, 190], 현재값: 90
# 137번째 이웃상태: [110, 380, 60, 90, 130, 20, 95, 180], 현재값: 80
# 138번째 이웃상태: [120, 70, 80, 140, 30, 105, 190], 현재값: 90
# 139번째 이웃상태: [90, 100, 110, 170, 60, 135], 현재값: 120
# 140번째 이웃상태: [140, 150, 160, 120, 110, 185], 현재값: 170
# 141번째 이웃상태: [140, 150, 160, 120, 110, 185], 현재값: 170
# 142번째 이웃상태: [90, 100, 110, 170, 60, 135], 현재값: 120
# 143번째 이웃상태: [70, 120, 90, 150, 40, 115, 200], 현재값: 100
# 144번째 이웃상태: [120, 170, 140, 100, 90, 165], 현재값: 150
# 145번째 이웃상태: [110, 160, 150, 90, 80, 155, 240], 현재값: 140
# 146번째 이웃상태: [210, 190, 180, 255, 140], 현재값: 240
# 147번째 이웃상태: [110, 160, 150, 90, 80, 155, 240], 현재값: 140
# 148번째 이웃상태: [125, 175, 165, 105, 95, 140, 255], 현재값: 155
# 149번째 이웃상태: [75, 405, 125, 115, 155, 45, 90, 205], 현재값: 105
# 150번째 이웃상태: [105, 375, 95, 85, 125, 15, 60, 175], 현재값: 75
# 151번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 152번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 153번째 이웃상태: [330, 0, 320, 310, 350, 360, 315, 400], 현재값: 300
# 154번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 155번째 이웃상태: [330, 0, 320, 310, 350, 360, 315, 400], 현재값: 300
# 156번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 157번째 이웃상태: [25, 315, 385, 310], 현재값: 325
# 158번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 159번째 이웃상태: [70, 360, 310, 385], 현재값: 370
# 160번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 161번째 이웃상태: [330, 0, 320, 310, 350, 360, 315, 400], 현재값: 300
# 162번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 163번째 이웃상태: [70, 360, 310, 385], 현재값: 370
# 164번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 165번째 이웃상태: [70, 360, 310, 385], 현재값: 370
# 166번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 167번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 168번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 169번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 170번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 171번째 이웃상태: [380, 50, 370, 360, 300, 410, 365], 현재값: 350
# 172번째 이웃상태: [70, 350, 320], 현재값: 370
# 173번째 이웃상태: [100, 370, 50, 80, 20, 130, 85, 170], 현재값: 70
# 174번째 이웃상태: [160, 110, 140, 80, 70, 145, 230], 현재값: 130
# 175번째 이웃상태: [170, 120, 130, 90, 80, 155], 현재값: 140
# 176번째 이웃상태: [140, 150, 160, 120, 110, 185], 현재값: 170
# 177번째 이웃상태: [170, 120, 130, 90, 80, 155], 현재값: 140
# 178번째 이웃상태: [120, 70, 80, 140, 30, 105, 190], 현재값: 90
# 179번째 이웃상태: [60, 330, 10, 20, 80, 90, 45, 130], 현재값: 30
# 180번째 이웃상태: [160, 110, 120, 180, 190, 145, 30], 현재값: 130
# 181번째 이웃상태: [125, 135, 205, 130, 45], 현재값: 145
# 182번째 이웃상태: [160, 110, 120, 180, 190, 145, 30], 현재값: 130
# 183번째 이웃상태: [125, 135, 205, 130, 45], 현재값: 145
# 184번째 이웃상태: [165, 115, 145, 185, 195, 120, 35], 현재값: 135
# 185번째 이웃상태: [135, 145, 225, 150, 65], 현재값: 165
# 186번째 이웃상태: [35, 45, 75, 115, 125, 50, 165], 현재값: 65
# 187번째 이웃상태: [135, 145, 225, 150, 65], 현재값: 165
# 188번째 이웃상태: [165, 115, 145, 185, 195, 120, 35], 현재값: 135
# 189번째 이웃상태: [165, 135, 245, 170, 85], 현재값: 185
# 190번째 이웃상태: [225, 195, 185, 230, 145], 현재값: 245
# 191번째 이웃상태: [175, 125, 155, 95, 85, 130, 245], 현재값: 145
# 192번째 이웃상태: [185, 135, 145, 105, 95, 140], 현재값: 155
# 193번째 이웃상태: [135, 85, 95, 155, 45, 90, 205], 현재값: 105
# 194번째 이웃상태: [185, 195, 145, 190, 105], 현재값: 205
# 195번째 이웃상태: [215, 205, 175, 235, 125, 170, 85], 현재값: 185
# 196번째 이웃상태: [155, 145, 115, 175, 185, 110, 25], 현재값: 125
# 197번째 이웃상태: [145, 135, 125, 165, 175, 100, 15], 현재값: 115
# 198번째 이웃상태: [155, 145, 115, 175, 185, 110, 25], 현재값: 125
# 199번째 이웃상태: [165, 125, 235, 160, 75], 현재값: 175
# 200번째 이웃상태: [105, 95, 65, 25, 135, 60, 175], 현재값: 75
# 201번째 이웃상태: [55, 325, 45, 15, 75, 85, 10, 125], 현재값: 25
# 202번째 이웃상태: [45, 315, 35, 25, 65, 75, 0, 115], 현재값: 15
# 203번째 이웃상태: [55, 325, 45, 15, 75, 85, 10, 125], 현재값: 25
# 204번째 이웃상태: [115, 385, 105, 75, 135, 25, 70, 185], 현재값: 85
# 205번째 이웃상태: [100, 370, 90, 60, 120, 10, 85, 170], 현재값: 70
# 206번째 이웃상태: [120, 70, 80, 140, 30, 105, 190], 현재값: 90
# 207번째 이웃상태: [135, 85, 95, 155, 45, 90, 205], 현재값: 105
# 208번째 이웃상태: [125, 395, 75, 105, 145, 35, 80, 195], 현재값: 95
# 209번째 이웃상태: [65, 335, 15, 45, 85, 95, 20, 135], 현재값: 35
# 210번째 이웃상태: [125, 395, 75, 105, 145, 35, 80, 195], 현재값: 95
# 211번째 이웃상태: [105, 375, 95, 85, 125, 15, 60, 175], 현재값: 75
# 212번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 213번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 214번째 이웃상태: [25, 315, 385, 310], 현재값: 325
# 215번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 216번째 이웃상태: [70, 360, 310, 385], 현재값: 370
# 217번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 218번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 219번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 220번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 221번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 222번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 223번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 224번째 이웃상태: [330, 0, 320, 310, 350, 360, 315, 400], 현재값: 300
# 225번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 226번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 227번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 228번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 229번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 230번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 231번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 232번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 233번째 이웃상태: [15, 345, 65, 55, 95, 105, 30, 145], 현재값: 45
# 234번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 235번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 236번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 237번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 238번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 239번째 이웃상태: [15, 345, 65, 55, 95, 105, 30, 145], 현재값: 45
# 240번째 이웃상태: [35, 45, 75, 115, 125, 50, 165], 현재값: 65
# 241번째 이웃상태: [85, 95, 125, 65, 175, 100], 현재값: 115
# 242번째 이웃상태: [95, 105, 115, 75, 185, 110], 현재값: 125
# 243번째 이웃상태: [80, 90, 100, 60, 170, 125], 현재값: 110
# 244번째 이웃상태: [95, 105, 115, 75, 185, 110], 현재값: 125
# 245번째 이웃상태: [75, 125, 95, 55, 165, 90], 현재값: 105
# 246번째 이웃상태: [65, 115, 105, 45, 155, 80, 195], 현재값: 95
# 247번째 이웃상태: [165, 145, 255, 180, 95], 현재값: 195
# 248번째 이웃상태: [65, 115, 105, 45, 155, 80, 195], 현재값: 95
# 249번째 이웃상태: [125, 175, 165, 105, 95, 140, 255], 현재값: 155
# 250번째 이웃상태: [110, 160, 150, 90, 80, 155, 240], 현재값: 140
# 251번째 이웃상태: [125, 175, 165, 105, 95, 140, 255], 현재값: 155
# 252번째 이웃상태: [225, 205, 195, 240, 155], 현재값: 255
# 253번째 이웃상태: [165, 145, 255, 180, 95], 현재값: 195
# 254번째 이웃상태: [195, 185, 175, 115, 225, 150, 65], 현재값: 165
# 255번째 이웃상태: [165, 135, 245, 170, 85], 현재값: 185
# 256번째 이웃상태: [200, 150, 180, 120, 230, 185, 70], 현재값: 170
# 257번째 이웃상태: [150, 100, 130, 170, 180, 135, 20], 현재값: 120
# 258번째 이웃상태: [210, 160, 190, 230, 120, 195, 80], 현재값: 180
# 259번째 이웃상태: [150, 100, 130, 170, 180, 135, 20], 현재값: 120
# 260번째 이웃상태: [160, 110, 120, 180, 190, 145, 30], 현재값: 130
# 261번째 이웃상태: [130, 140, 150, 60], 현재값: 160
# 262번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 263번째 이웃상태: [10, 340, 60, 30, 90, 100, 55, 140], 현재값: 40
# 264번째 이웃상태: [70, 120, 90, 150, 40, 115, 200], 현재값: 100
# 265번째 이웃상태: [170, 190, 140, 215, 100], 현재값: 200
# 266번째 이웃상태: [160, 210, 200, 240, 130, 205, 90], 현재값: 190
# 267번째 이웃상태: [190, 180, 170, 210, 100, 175, 60], 현재값: 160
# 268번째 이웃상태: [160, 210, 200, 240, 130, 205, 90], 현재값: 190
# 269번째 이웃상태: [210, 190, 180, 255, 140], 현재값: 240
# 270번째 이웃상태: [150, 200, 190, 130, 240, 195, 80], 현재값: 180
# 271번째 이웃상태: [160, 180, 140, 90], 현재값: 190
# 272번째 이웃상태: [60, 110, 80, 40, 150, 105, 190], 현재값: 90
# 273번째 이웃상태: [90, 360, 80, 50, 10, 120, 75, 160], 현재값: 60
# 274번째 이웃상태: [60, 110, 80, 40, 150, 105, 190], 현재값: 90
# 275번째 이웃상태: [90, 360, 80, 50, 10, 120, 75, 160], 현재값: 60
# 276번째 이웃상태: [105, 95, 65, 25, 135, 60, 175], 현재값: 75
# 277번째 이웃상태: [90, 360, 80, 50, 10, 120, 75, 160], 현재값: 60
# 278번째 이웃상태: [150, 140, 110, 70, 60, 135, 220], 현재값: 120
# 279번째 이웃상태: [100, 370, 90, 60, 120, 10, 85, 170], 현재값: 70
# 280번째 이웃상태: [40, 310, 30, 0, 60, 70, 25, 110], 현재값: 10
# 281번째 이웃상태: [60, 330, 10, 20, 80, 90, 45, 130], 현재값: 30
# 282번째 이웃상태: [40, 310, 30, 0, 60, 70, 25, 110], 현재값: 10
# 283번째 이웃상태: [140, 130, 100, 160, 170, 125, 10], 현재값: 110
# 284번째 이웃상태: [40, 310, 30, 0, 60, 70, 25, 110], 현재값: 10
# 285번째 이웃상태: [100, 370, 90, 60, 120, 10, 85, 170], 현재값: 70
# 286번째 이웃상태: [70, 360, 310, 385], 현재값: 370
# 287번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 288번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 289번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 290번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 291번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 292번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 293번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 294번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 295번째 이웃상태: [65, 315, 425, 350], 현재값: 365
# 296번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 297번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 298번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 299번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 300번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 301번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 302번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 303번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 304번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 305번째 이웃상태: [70, 350, 320], 현재값: 370
# 306번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 307번째 이웃상태: [35, 315, 395, 320], 현재값: 335
# 308번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 309번째 이웃상태: [65, 315, 425, 350], 현재값: 365
# 310번째 이웃상태: [380, 50, 370, 360, 300, 410, 365], 현재값: 350
# 311번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 312번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 313번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 314번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 315번째 이웃상태: [35, 315, 395, 320], 현재값: 335
# 316번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 317번째 이웃상태: [25, 315, 385, 310], 현재값: 325
# 318번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 319번째 이웃상태: [60, 350, 310], 현재값: 360
# 320번째 이웃상태: [90, 360, 80, 50, 10, 120, 75, 160], 현재값: 60
# 321번째 이웃상태: [60, 110, 80, 40, 150, 105, 190], 현재값: 90
# 322번째 이웃상태: [75, 125, 95, 55, 165, 90], 현재값: 105
# 323번째 이웃상태: [65, 115, 105, 45, 155, 80, 195], 현재값: 95
# 324번째 이웃상태: [165, 145, 255, 180, 95], 현재값: 195
# 325번째 이웃상태: [150, 200, 190, 130, 240, 195, 80], 현재값: 180
# 326번째 이웃상태: [210, 190, 180, 255, 140], 현재값: 240
# 327번째 이웃상태: [150, 200, 190, 130, 240, 195, 80], 현재값: 180
# 328번째 이웃상태: [160, 180, 140, 90], 현재값: 190
# 329번째 이웃상태: [110, 160, 130, 190, 200, 155, 40], 현재값: 140
# 330번째 이웃상태: [160, 180, 140, 90], 현재값: 190
# 331번째 이웃상태: [110, 160, 130, 190, 200, 155, 40], 현재값: 140
# 332번째 이웃상태: [130, 140, 150, 60], 현재값: 160
# 333번째 이웃상태: [120, 130, 160, 200, 210, 165, 50], 현재값: 150
# 334번째 이웃상태: [150, 100, 130, 170, 180, 135, 20], 현재값: 120
# 335번째 이웃상태: [130, 400, 120, 110, 150, 160, 115, 0], 현재값: 100
# 336번째 이웃상태: [145, 135, 125, 165, 175, 100, 15], 현재값: 115
# 337번째 이웃상태: [165, 115, 145, 185, 195, 120, 35], 현재값: 135
# 338번째 이웃상태: [150, 100, 130, 170, 180, 135, 20], 현재값: 120
# 339번째 이웃상태: [120, 130, 160, 200, 210, 165, 50], 현재값: 150
# 340번째 이웃상태: [180, 190, 150, 225, 110], 현재값: 210
# 341번째 이웃상태: [195, 205, 165, 210, 125], 현재값: 225
# 342번째 이웃상태: [95, 105, 135, 175, 65, 110, 225], 현재값: 125
# 343번째 이웃상태: [35, 45, 75, 115, 125, 50, 165], 현재값: 65
# 344번째 이웃상태: [15, 345, 65, 55, 95, 105, 30, 145], 현재값: 45
# 345번째 이웃상태: [35, 45, 75, 115, 125, 50, 165], 현재값: 65
# 346번째 이웃상태: [20, 350, 30, 60, 100, 110, 65, 150], 현재값: 50
# 347번째 이웃상태: [0, 330, 50, 40, 80, 90, 45, 130], 현재값: 30
# 348번째 이웃상태: [50, 380, 100, 90, 30, 140, 95, 180], 현재값: 80
# 349번째 이웃상태: [150, 200, 190, 130, 240, 195, 80], 현재값: 180
# 350번째 이웃상태: [100, 150, 140, 180, 190, 145, 30], 현재값: 130
# 351번째 이웃상태: [130, 400, 120, 110, 150, 160, 115, 0], 현재값: 100
# 352번째 이웃상태: [140, 130, 100, 160, 170, 125, 10], 현재값: 110
# 353번째 이웃상태: [40, 310, 30, 0, 60, 70, 25, 110], 현재값: 10
# 354번째 이웃상태: [90, 360, 80, 50, 10, 120, 75, 160], 현재값: 60
# 355번째 이웃상태: [110, 60, 70, 30, 140, 95, 180], 현재값: 80
# 356번째 이웃상태: [170, 120, 130, 90, 80, 155], 현재값: 140
# 357번째 이웃상태: [120, 70, 80, 140, 30, 105, 190], 현재값: 90
# 358번째 이웃상태: [170, 180, 130, 205, 90], 현재값: 190
# 359번째 이웃상태: [160, 110, 120, 180, 190, 145, 30], 현재값: 130
# 360번째 이웃상태: [125, 135, 205, 130, 45], 현재값: 145
# 361번째 이웃상태: [185, 195, 145, 190, 105], 현재값: 205
# 362번째 이웃상태: [135, 85, 95, 155, 45, 90, 205], 현재값: 105
# 363번째 이웃상태: [75, 25, 35, 95, 105, 30, 145], 현재값: 45
# 364번째 이웃상태: [135, 85, 95, 155, 45, 90, 205], 현재값: 105
# 365번째 이웃상태: [75, 25, 35, 95, 105, 30, 145], 현재값: 45
# 366번째 이웃상태: [45, 55, 65, 125, 135, 60], 현재값: 75
# 367번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 368번째 이웃상태: [60, 330, 10, 20, 80, 90, 45, 130], 현재값: 30
# 369번째 이웃상태: [30, 310, 320], 현재값: 330
# 370번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 371번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 372번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 373번째 이웃상태: [320, 50, 330], 현재값: 350
# 374번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 375번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 376번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 377번째 이웃상태: [35, 315, 395, 320], 현재값: 335
# 378번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 379번째 이웃상태: [45, 315, 35, 25, 65, 75, 0, 115], 현재값: 15
# 380번째 이웃상태: [15, 345, 65, 55, 95, 105, 30, 145], 현재값: 45
# 381번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 382번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 383번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 384번째 이웃상태: [15, 345, 65, 55, 95, 105, 30, 145], 현재값: 45
# 385번째 이웃상태: [65, 115, 105, 45, 155, 80, 195], 현재값: 95
# 386번째 이웃상태: [125, 175, 165, 105, 95, 140, 255], 현재값: 155
# 387번째 이웃상태: [145, 155, 185, 125, 115, 160], 현재값: 175
# 388번째 이웃상태: [130, 140, 170, 110, 100, 175], 현재값: 160
# 389번째 이웃상태: [145, 155, 185, 125, 115, 160], 현재값: 175
# 390번째 이웃상태: [125, 175, 165, 105, 95, 140, 255], 현재값: 155
# 391번째 이웃상태: [135, 185, 155, 115, 105, 150], 현재값: 165
# 392번째 이웃상태: [125, 175, 165, 105, 95, 140, 255], 현재값: 155
# 393번째 이웃상태: [135, 185, 155, 115, 105, 150], 현재값: 165
# 394번째 이웃상태: [155, 165, 175, 135, 125, 170], 현재값: 185
# 395번째 이웃상태: [185, 135, 145, 105, 95, 140], 현재값: 155
# 396번째 이웃상태: [165, 155, 125, 85, 75, 120, 235], 현재값: 135
# 397번째 이웃상태: [150, 140, 110, 70, 60, 135, 220], 현재값: 120
# 398번째 이웃상태: [170, 120, 130, 90, 80, 155], 현재값: 140
# 399번째 이웃상태: [160, 110, 140, 80, 70, 145, 230], 현재값: 130
# 400번째 이웃상태: [140, 410, 130, 120, 60, 50, 125, 210], 현재값: 110
# 401번째 이웃상태: [80, 350, 70, 60, 0, 110, 65, 150], 현재값: 50
# 402번째 이웃상태: [95, 365, 85, 75, 15, 125, 50, 165], 현재값: 65
# 403번째 이웃상태: [45, 315, 35, 25, 65, 75, 0, 115], 현재값: 15
# 404번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 405번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 406번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 407번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 408번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 409번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 410번째 이웃상태: [25, 315, 385, 310], 현재값: 325
# 411번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 412번째 이웃상태: [115, 385, 105, 75, 135, 25, 70, 185], 현재값: 85
# 413번째 이웃상태: [85, 135, 105, 165, 55, 100, 215], 현재값: 115
# 414번째 이웃상태: [185, 205, 155, 200, 115], 현재값: 215
# 415번째 이웃상태: [85, 135, 105, 165, 55, 100, 215], 현재값: 115
# 416번째 이웃상태: [70, 120, 90, 150, 40, 115, 200], 현재값: 100
# 417번째 이웃상태: [90, 100, 110, 170, 60, 135], 현재값: 120
# 418번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 419번째 이웃상태: [130, 140, 150, 60], 현재값: 160
# 420번째 이웃상태: [160, 110, 120, 180, 190, 145, 30], 현재값: 130
# 421번째 이웃상태: [160, 170, 130, 80], 현재값: 180
# 422번째 이웃상태: [190, 180, 150, 110, 220, 175, 60], 현재값: 160
# 423번째 이웃상태: [165, 125, 235, 160, 75], 현재값: 175
# 424번째 이웃상태: [105, 95, 65, 25, 135, 60, 175], 현재값: 75
# 425번째 이웃상태: [125, 75, 85, 45, 155, 80], 현재값: 95
# 426번째 이웃상태: [115, 65, 95, 35, 145, 70, 185], 현재값: 85
# 427번째 이웃상태: [175, 125, 155, 95, 85, 130, 245], 현재값: 145
# 428번째 이웃상태: [155, 425, 145, 135, 75, 65, 110, 225], 현재값: 125
# 429번째 이웃상태: [125, 175, 165, 105, 95, 140, 255], 현재값: 155
# 430번째 이웃상태: [135, 185, 155, 115, 105, 150], 현재값: 165
# 431번째 이웃상태: [75, 125, 95, 55, 165, 90], 현재값: 105
# 432번째 이웃상태: [105, 95, 65, 25, 135, 60, 175], 현재값: 75
# 433번째 이웃상태: [165, 155, 125, 85, 75, 120, 235], 현재값: 135
# 434번째 이웃상태: [150, 140, 110, 70, 60, 135, 220], 현재값: 120
# 435번째 이웃상태: [165, 155, 125, 85, 75, 120, 235], 현재값: 135
# 436번째 이웃상태: [135, 185, 155, 115, 105, 150], 현재값: 165
# 437번째 이웃상태: [165, 155, 125, 85, 75, 120, 235], 현재값: 135
# 438번째 이웃상태: [115, 385, 105, 75, 135, 25, 70, 185], 현재값: 85
# 439번째 이웃상태: [105, 375, 95, 85, 125, 15, 60, 175], 현재값: 75
# 440번째 이웃상태: [205, 195, 185, 225, 115, 160, 75], 현재값: 175
# 441번째 이웃상태: [255, 245, 235, 175, 165, 210, 125], 현재값: 225
# 442번째 이웃상태: [225, 185, 175, 220, 135], 현재값: 235
# 443번째 이웃상태: [165, 155, 125, 85, 75, 120, 235], 현재값: 135
# 444번째 이웃상태: [135, 185, 155, 115, 105, 150], 현재값: 165
# 445번째 이웃상태: [125, 175, 165, 105, 95, 140, 255], 현재값: 155
# 446번째 이웃상태: [145, 155, 185, 125, 115, 160], 현재값: 175
# 447번째 이웃상태: [130, 140, 170, 110, 100, 175], 현재값: 160
# 448번째 이웃상태: [140, 150, 160, 120, 110, 185], 현재값: 170
# 449번째 이웃상태: [155, 165, 175, 135, 125, 170], 현재값: 185
# 450번째 이웃상태: [105, 115, 125, 185, 75, 120], 현재값: 135
# 451번째 이웃상태: [90, 100, 110, 170, 60, 135], 현재값: 120
# 452번째 이웃상태: [120, 70, 80, 140, 30, 105, 190], 현재값: 90
# 453번째 이웃상태: [100, 370, 90, 60, 120, 10, 85, 170], 현재값: 70
# 454번째 이웃상태: [150, 140, 110, 70, 60, 135, 220], 현재값: 120
# 455번째 이웃상태: [165, 155, 125, 85, 75, 120, 235], 현재값: 135
# 456번째 이웃상태: [155, 425, 145, 135, 75, 65, 110, 225], 현재값: 125
# 457번째 이웃상태: [105, 375, 95, 85, 125, 15, 60, 175], 현재값: 75
# 458번째 이웃상태: [75, 405, 125, 115, 155, 45, 90, 205], 현재값: 105
# 459번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 460번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 461번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 462번째 이웃상태: [0, 330, 50, 40, 80, 90, 45, 130], 현재값: 30
# 463번째 이웃상태: [20, 350, 30, 60, 100, 110, 65, 150], 현재값: 50
# 464번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 465번째 이웃상태: [130, 140, 150, 60], 현재값: 160
# 466번째 이웃상태: [120, 130, 160, 200, 210, 165, 50], 현재값: 150
# 467번째 이웃상태: [150, 100, 130, 170, 180, 135, 20], 현재값: 120
# 468번째 이웃상태: [200, 150, 180, 120, 230, 185, 70], 현재값: 170
# 469번째 이웃상태: [100, 370, 50, 80, 20, 130, 85, 170], 현재값: 70
# 470번째 이웃상태: [115, 65, 95, 35, 145, 70, 185], 현재값: 85
# 471번째 이웃상태: [95, 365, 85, 75, 15, 125, 50, 165], 현재값: 65
# 472번째 이웃상태: [65, 315, 425, 350], 현재값: 365
# 473번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 474번째 이웃상태: [155, 425, 145, 135, 75, 65, 110, 225], 현재값: 125
# 475번째 이웃상태: [165, 155, 125, 85, 75, 120, 235], 현재값: 135
# 476번째 이웃상태: [185, 135, 145, 105, 95, 140], 현재값: 155
# 477번째 이웃상태: [155, 165, 175, 135, 125, 170], 현재값: 185
# 478번째 이웃상태: [140, 150, 160, 120, 110, 185], 현재값: 170
# 479번째 이웃상태: [155, 165, 175, 135, 125, 170], 현재값: 185
# 480번째 이웃상태: [105, 115, 125, 185, 75, 120], 현재값: 135
# 481번째 이웃상태: [95, 105, 135, 175, 65, 110, 225], 현재값: 125
# 482번째 이웃상태: [35, 45, 75, 115, 125, 50, 165], 현재값: 65
# 483번째 이웃상태: [45, 55, 65, 125, 135, 60], 현재값: 75
# 484번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 485번째 이웃상태: [80, 90, 100, 60, 170, 125], 현재값: 110
# 486번째 이웃상태: [60, 110, 80, 40, 150, 105, 190], 현재값: 90
# 487번째 이웃상태: [160, 180, 140, 90], 현재값: 190
# 488번째 이웃상태: [190, 180, 150, 110, 220, 175, 60], 현재값: 160
# 489번째 이웃상태: [160, 180, 140, 90], 현재값: 190
# 490번째 이웃상태: [110, 160, 130, 190, 200, 155, 40], 현재값: 140
# 491번째 이웃상태: [160, 180, 140, 90], 현재값: 190
# 492번째 이웃상태: [150, 200, 190, 130, 240, 195, 80], 현재값: 180
# 493번째 이웃상태: [165, 145, 255, 180, 95], 현재값: 195
# 494번째 이웃상태: [150, 200, 190, 130, 240, 195, 80], 현재값: 180
# 495번째 이웃상태: [100, 150, 140, 180, 190, 145, 30], 현재값: 130
# 496번째 이웃상태: [115, 165, 155, 195, 205, 130, 45], 현재값: 145
# 497번째 이웃상태: [175, 225, 215, 255, 145, 190, 105], 현재값: 205
# 498번째 이웃상태: [205, 195, 185, 225, 115, 160, 75], 현재값: 175
# 499번째 이웃상태: [105, 375, 95, 85, 125, 15, 60, 175], 현재값: 75
# 500번째 이웃상태: [125, 395, 75, 105, 145, 35, 80, 195], 현재값: 95
# 501번째 이웃상태: [105, 375, 95, 85, 125, 15, 60, 175], 현재값: 75
# 502번째 이웃상태: [125, 395, 75, 105, 145, 35, 80, 195], 현재값: 95
# 503번째 이웃상태: [65, 335, 15, 45, 85, 95, 20, 135], 현재값: 35
# 504번째 이웃상태: [45, 315, 35, 25, 65, 75, 0, 115], 현재값: 15
# 505번째 이웃상태: [105, 375, 95, 85, 125, 15, 60, 175], 현재값: 75
# 506번째 이웃상태: [125, 395, 75, 105, 145, 35, 80, 195], 현재값: 95
# 507번째 이웃상태: [175, 125, 155, 95, 85, 130, 245], 현재값: 145
# 508번째 이웃상태: [145, 155, 185, 125, 115, 160], 현재값: 175
# 509번째 이웃상태: [130, 140, 170, 110, 100, 175], 현재값: 160
# 510번째 이웃상태: [160, 110, 140, 80, 70, 145, 230], 현재값: 130
# 511번째 이웃상태: [175, 125, 155, 95, 85, 130, 245], 현재값: 145
# 512번째 이웃상태: [175, 125, 155, 95, 85, 130, 245], 현재값: 145
# 513번째 이웃상태: [115, 65, 95, 35, 145, 70, 185], 현재값: 85
# 514번째 이웃상태: [85, 95, 125, 65, 175, 100], 현재값: 115
# 515번째 이웃상태: [85, 95, 125, 65, 175, 100], 현재값: 115
# 516번째 이웃상태: [35, 45, 75, 115, 125, 50, 165], 현재값: 65
# 517번째 이웃상태: [135, 145, 225, 150, 65], 현재값: 165
# 518번째 이웃상태: [195, 205, 165, 210, 125], 현재값: 225
# 519번째 이웃상태: [180, 190, 150, 225, 110], 현재값: 210
# 520번째 이웃상태: [195, 205, 165, 210, 125], 현재값: 225
# 521번째 이웃상태: [175, 225, 215, 255, 145, 190, 105], 현재값: 205
# 522번째 이웃상태: [185, 205, 155, 200, 115], 현재값: 215
# 523번째 이웃상태: [170, 190, 140, 215, 100], 현재값: 200
# 524번째 이웃상태: [200, 190, 160, 220, 110, 185, 70], 현재값: 170
# 525번째 이웃상태: [210, 170, 160, 235, 120], 현재값: 220
# 526번째 이웃상태: [240, 230, 220, 160, 150, 225, 110], 현재값: 210
# 527번째 이웃상태: [190, 180, 170, 210, 100, 175, 60], 현재값: 160
# 528번째 이웃상태: [130, 400, 120, 110, 150, 160, 115, 0], 현재값: 100
# 529번째 이웃상태: [100, 150, 140, 180, 190, 145, 30], 현재값: 130
# 530번째 이웃상태: [0, 330, 50, 40, 80, 90, 45, 130], 현재값: 30
# 531번째 이웃상태: [50, 380, 100, 90, 30, 140, 95, 180], 현재값: 80
# 532번째 이웃상태: [70, 80, 110, 50, 160, 115, 200], 현재값: 100
# 533번째 이웃상태: [170, 180, 150, 100], 현재값: 200
# 534번째 이웃상태: [200, 150, 180, 120, 230, 185, 70], 현재값: 170
# 535번째 이웃상태: [170, 180, 150, 100], 현재값: 200
# 536번째 이웃상태: [170, 180, 150, 100], 현재값: 200
# 537번째 이웃상태: [70, 80, 110, 50, 160, 115, 200], 현재값: 100
# 538번째 이웃상태: [170, 180, 150, 100], 현재값: 200
# 539번째 이웃상태: [150, 200, 190, 130, 240, 195, 80], 현재값: 180
# 540번째 이웃상태: [170, 180, 150, 100], 현재값: 200
# 541번째 이웃상태: [70, 80, 110, 50, 160, 115, 200], 현재값: 100
# 542번째 이웃상태: [20, 350, 30, 60, 100, 110, 65, 150], 현재값: 50
# 543번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 544번째 이웃상태: [60, 330, 10, 20, 80, 90, 45, 130], 현재값: 30
# 545번째 이웃상태: [110, 60, 70, 30, 140, 95, 180], 현재값: 80
# 546번째 이웃상태: [60, 330, 10, 20, 80, 90, 45, 130], 현재값: 30
# 547번째 이웃상태: [40, 310, 30, 0, 60, 70, 25, 110], 현재값: 10
# 548번째 이웃상태: [30, 300, 20, 10, 50, 60, 15, 100], 현재값: 0
# 549번째 이웃상태: [50, 320, 0, 30, 70, 80, 35, 120], 현재값: 20
# 550번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 551번째 이웃상태: [30, 310, 320], 현재값: 330
# 552번째 이웃상태: [60, 330, 10, 20, 80, 90, 45, 130], 현재값: 30
# 553번째 이웃상태: [30, 310, 320], 현재값: 330
# 554번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 555번째 이웃상태: [30, 310, 320], 현재값: 330
# 556번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 557번째 이웃상태: [310, 40, 330], 현재값: 340
# 558번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 559번째 이웃상태: [310, 40, 330], 현재값: 340
# 560번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 561번째 이웃상태: [310, 40, 330], 현재값: 340
# 562번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 563번째 이웃상태: [60, 350, 310], 현재값: 360
# 564번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 565번째 이웃상태: [25, 315, 385, 310], 현재값: 325
# 566번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 567번째 이웃상태: [70, 360, 310, 385], 현재값: 370
# 568번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 569번째 이웃상태: [330, 0, 320, 310, 350, 360, 315, 400], 현재값: 300
# 570번째 이웃상태: [380, 50, 370, 360, 300, 410, 365], 현재값: 350
# 571번째 이웃상태: [350, 80, 330], 현재값: 380
# 572번째 이웃상태: [380, 50, 370, 360, 300, 410, 365], 현재값: 350
# 573번째 이웃상태: [60, 350, 310], 현재값: 360
# 574번째 이웃상태: [380, 50, 370, 360, 300, 410, 365], 현재값: 350
# 575번째 이웃상태: [70, 350, 320], 현재값: 370
# 576번째 이웃상태: [100, 370, 50, 80, 20, 130, 85, 170], 현재값: 70
# 577번째 이웃상태: [70, 350, 320], 현재값: 370
# 578번째 이웃상태: [380, 50, 370, 360, 300, 410, 365], 현재값: 350
# 579번째 이웃상태: [380, 50, 370, 360, 300, 410, 365], 현재값: 350
# 580번째 이웃상태: [350, 80, 330], 현재값: 380
# 581번째 이웃상태: [380, 50, 370, 360, 300, 410, 365], 현재값: 350
# 582번째 이웃상태: [350, 80, 330], 현재값: 380
# 583번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 584번째 이웃상태: [310, 40, 330], 현재값: 340
# 585번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 586번째 이웃상태: [310, 40, 330], 현재값: 340
# 587번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 588번째 이웃상태: [330, 0, 320, 310, 350, 360, 315, 400], 현재값: 300
# 589번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 590번째 이웃상태: [330, 0, 320, 310, 350, 360, 315, 400], 현재값: 300
# 591번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 592번째 이웃상태: [50, 320, 0, 30, 70, 80, 35, 120], 현재값: 20
# 593번째 이웃상태: [20, 350, 30, 60, 100, 110, 65, 150], 현재값: 50
# 594번째 이웃상태: [320, 50, 330], 현재값: 350
# 595번째 이웃상태: [20, 350, 30, 60, 100, 110, 65, 150], 현재값: 50
# 596번째 이웃상태: [80, 90, 120, 160, 50, 125, 210], 현재값: 110
# 597번째 이웃상태: [180, 190, 150, 225, 110], 현재값: 210
# 598번째 이웃상태: [160, 210, 200, 240, 130, 205, 90], 현재값: 190
# 599번째 이웃상태: [175, 225, 215, 255, 145, 190, 105], 현재값: 205
# 600번째 이웃상태: [175, 225, 215, 255, 145, 190, 105], 현재값: 205
# 601번째 이웃상태: [115, 165, 155, 195, 205, 130, 45], 현재값: 145
# 602번째 이웃상태: [125, 145, 215, 140, 55], 현재값: 155
# 603번째 이웃상태: [155, 145, 115, 175, 185, 110, 25], 현재값: 125
# 604번째 이웃상태: [155, 145, 115, 175, 185, 110, 25], 현재값: 125
# 605번째 이웃상태: [155, 145, 115, 175, 185, 110, 25], 현재값: 125
# 606번째 이웃상태: [125, 145, 215, 140, 55], 현재값: 155
# 607번째 이웃상태: [185, 205, 155, 200, 115], 현재값: 215
# 608번째 이웃상태: [215, 205, 175, 235, 125, 170, 85], 현재값: 185
# 609번째 이웃상태: [215, 205, 175, 235, 125, 170, 85], 현재값: 185
# 610번째 이웃상태: [200, 190, 160, 220, 110, 185, 70], 현재값: 170
# 611번째 이웃상태: [215, 205, 175, 235, 125, 170, 85], 현재값: 185
# 612번째 이웃상태: [205, 195, 185, 225, 115, 160, 75], 현재값: 175
# 613번째 이웃상태: [215, 205, 175, 235, 125, 170, 85], 현재값: 185
# 614번째 이웃상태: [215, 205, 175, 235, 125, 170, 85], 현재값: 185
# 615번째 이웃상태: [115, 385, 105, 75, 135, 25, 70, 185], 현재값: 85
# 616번째 이웃상태: [135, 85, 95, 155, 45, 90, 205], 현재값: 105
# 617번째 이웃상태: [185, 135, 145, 105, 95, 140], 현재값: 155
# 618번째 이웃상태: [165, 155, 125, 85, 75, 120, 235], 현재값: 135
# 619번째 이웃상태: [155, 425, 145, 135, 75, 65, 110, 225], 현재값: 125
# 620번째 이웃상태: [165, 155, 125, 85, 75, 120, 235], 현재값: 135
# 621번째 이웃상태: [105, 95, 65, 25, 135, 60, 175], 현재값: 75
# 622번째 이웃상태: [125, 75, 85, 45, 155, 80], 현재값: 95
# 623번째 이웃상태: [75, 25, 35, 95, 105, 30, 145], 현재값: 45
# 624번째 이웃상태: [55, 325, 45, 15, 75, 85, 10, 125], 현재값: 25
# 625번째 이웃상태: [75, 25, 35, 95, 105, 30, 145], 현재값: 45
# 626번째 이웃상태: [65, 335, 15, 45, 85, 95, 20, 135], 현재값: 35
# 627번째 이웃상태: [75, 25, 35, 95, 105, 30, 145], 현재값: 45
# 628번째 이웃상태: [60, 330, 10, 20, 80, 90, 45, 130], 현재값: 30
# 629번째 이웃상태: [50, 320, 0, 30, 70, 80, 35, 120], 현재값: 20
# 630번째 이웃상태: [110, 380, 60, 90, 130, 20, 95, 180], 현재값: 80
# 631번째 이웃상태: [80, 90, 120, 160, 50, 125, 210], 현재값: 110
# 632번째 이웃상태: [110, 380, 60, 90, 130, 20, 95, 180], 현재값: 80
# 633번째 이웃상태: [80, 90, 120, 160, 50, 125, 210], 현재값: 110
# 634번째 이웃상태: [90, 100, 110, 170, 60, 135], 현재값: 120
# 635번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 636번째 이웃상태: [45, 55, 65, 125, 135, 60], 현재값: 75
# 637번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 638번째 이웃상태: [20, 350, 30, 60, 100, 110, 65, 150], 현재값: 50
# 639번째 이웃상태: [320, 50, 330], 현재값: 350
# 640번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 641번째 이웃상태: [320, 50, 330], 현재값: 350
# 642번째 이웃상태: [320, 50, 330], 현재값: 350
# 643번째 이웃상태: [320, 50, 330], 현재값: 350
# 644번째 이웃상태: [20, 350, 30, 60, 100, 110, 65, 150], 현재값: 50
# 645번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 646번째 이웃상태: [80, 90, 100, 60, 170, 125], 현재값: 110
# 647번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 648번째 이웃상태: [45, 55, 65, 125, 135, 60], 현재값: 75
# 649번째 이웃상태: [25, 75, 45, 105, 115, 40, 155], 현재값: 55
# 650번째 이웃상태: [45, 55, 65, 125, 135, 60], 현재값: 75
# 651번째 이웃상태: [105, 115, 125, 185, 75, 120], 현재값: 135
# 652번째 이웃상태: [155, 165, 175, 135, 125, 170], 현재값: 185
# 653번째 이웃상태: [185, 135, 145, 105, 95, 140], 현재값: 155
# 654번째 이웃상태: [155, 165, 175, 135, 125, 170], 현재값: 185
# 655번째 이웃상태: [155, 165, 175, 135, 125, 170], 현재값: 185
# 656번째 이웃상태: [95, 105, 115, 75, 185, 110], 현재값: 125
# 657번째 이웃상태: [45, 55, 65, 125, 135, 60], 현재값: 75
# 658번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 659번째 이웃상태: [90, 100, 110, 170, 60, 135], 현재값: 120
# 660번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 661번째 이웃상태: [10, 340, 60, 30, 90, 100, 55, 140], 현재값: 40
# 662번째 이웃상태: [0, 330, 50, 40, 80, 90, 45, 130], 현재값: 30
# 663번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 664번째 이웃상태: [350, 80, 330], 현재값: 380
# 665번째 이웃상태: [380, 50, 370, 360, 300, 410, 365], 현재값: 350
# 666번째 이웃상태: [80, 350, 70, 60, 0, 110, 65, 150], 현재값: 50
# 667번째 이웃상태: [50, 380, 100, 90, 30, 140, 95, 180], 현재값: 80
# 668번째 이웃상태: [350, 80, 330], 현재값: 380
# 669번째 이웃상태: [350, 80, 330], 현재값: 380
# 670번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 671번째 이웃상태: [350, 80, 330], 현재값: 380
# 672번째 이웃상태: [350, 80, 330], 현재값: 380
# 673번째 이웃상태: [350, 80, 330], 현재값: 380
# 674번째 이웃상태: [50, 380, 100, 90, 30, 140, 95, 180], 현재값: 80
# 675번째 이웃상태: [80, 350, 70, 60, 0, 110, 65, 150], 현재값: 50
# 676번째 이웃상태: [90, 360, 80, 50, 10, 120, 75, 160], 현재값: 60
# 677번째 이웃상태: [80, 350, 70, 60, 0, 110, 65, 150], 현재값: 50
# 678번째 이웃상태: [50, 380, 100, 90, 30, 140, 95, 180], 현재값: 80
# 679번째 이웃상태: [65, 115, 105, 45, 155, 80, 195], 현재값: 95
# 680번째 이웃상태: [85, 95, 125, 65, 175, 100], 현재값: 115
# 681번째 이웃상태: [70, 80, 110, 50, 160, 115, 200], 현재값: 100
# 682번째 이웃상태: [170, 180, 150, 100], 현재값: 200
# 683번째 이웃상태: [120, 130, 160, 200, 210, 165, 50], 현재값: 150
# 684번째 이웃상태: [135, 145, 225, 150, 65], 현재값: 165
# 685번째 이웃상태: [195, 205, 165, 210, 125], 현재값: 225
# 686번째 이웃상태: [175, 225, 215, 255, 145, 190, 105], 현재값: 205
# 687번째 이웃상태: [185, 205, 155, 200, 115], 현재값: 215
# 688번째 이웃상태: [215, 205, 175, 235, 125, 170, 85], 현재값: 185
# 689번째 이웃상태: [185, 195, 145, 190, 105], 현재값: 205
# 690번째 이웃상태: [215, 205, 175, 235, 125, 170, 85], 현재값: 185
# 691번째 이웃상태: [185, 195, 145, 190, 105], 현재값: 205
# 692번째 이웃상태: [215, 205, 175, 235, 125, 170, 85], 현재값: 185
# 693번째 이웃상태: [205, 195, 185, 225, 115, 160, 75], 현재값: 175
# 694번째 이웃상태: [215, 205, 175, 235, 125, 170, 85], 현재값: 185
# 695번째 이웃상태: [185, 195, 145, 190, 105], 현재값: 205
# 696번째 이웃상태: [170, 180, 130, 205, 90], 현재값: 190
# 697번째 이웃상태: [200, 190, 160, 220, 110, 185, 70], 현재값: 170
# 698번째 이웃상태: [140, 130, 100, 160, 170, 125, 10], 현재값: 110
# 699번째 이웃상태: [160, 110, 120, 180, 190, 145, 30], 현재값: 130
# 700번째 이웃상태: [150, 100, 130, 170, 180, 135, 20], 현재값: 120
# 701번째 이웃상태: [150, 100, 130, 170, 180, 135, 20], 현재값: 120
# 702번째 이웃상태: [160, 110, 120, 180, 190, 145, 30], 현재값: 130
# 703번째 이웃상태: [60, 330, 10, 20, 80, 90, 45, 130], 현재값: 30
# 704번째 이웃상태: [160, 110, 120, 180, 190, 145, 30], 현재값: 130
# 705번째 이웃상태: [160, 170, 130, 80], 현재값: 180
# 706번째 이웃상태: [160, 170, 130, 80], 현재값: 180
# 707번째 이웃상태: [160, 110, 120, 180, 190, 145, 30], 현재값: 130
# 708번째 이웃상태: [130, 140, 150, 60], 현재값: 160
# 709번째 이웃상태: [130, 140, 150, 60], 현재값: 160
# 710번째 이웃상태: [160, 110, 120, 180, 190, 145, 30], 현재값: 130
# 711번째 이웃상태: [150, 100, 130, 170, 180, 135, 20], 현재값: 120
# 712번째 이웃상태: [210, 160, 190, 230, 120, 195, 80], 현재값: 180
# 713번째 이웃상태: [190, 180, 170, 210, 100, 175, 60], 현재값: 160
# 714번째 이웃상태: [240, 230, 220, 160, 150, 225, 110], 현재값: 210
# 715번째 이웃상태: [255, 245, 235, 175, 165, 210, 125], 현재값: 225
# 716번째 이웃상태: [255, 245, 235, 175, 165, 210, 125], 현재값: 225
# 717번째 이웃상태: [225, 195, 185, 230, 145], 현재값: 245
# 718번째 이웃상태: [255, 245, 235, 175, 165, 210, 125], 현재값: 225
# 719번째 이웃상태: [155, 425, 145, 135, 75, 65, 110, 225], 현재값: 125
# 720번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 721번째 이웃상태: [65, 315, 425, 350], 현재값: 365
# 722번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 723번째 이웃상태: [65, 315, 425, 350], 현재값: 365
# 724번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 725번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 726번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 727번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 728번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 729번째 이웃상태: [320, 50, 330], 현재값: 350
# 730번째 이웃상태: [320, 50, 330], 현재값: 350
# 731번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 732번째 이웃상태: [30, 310, 320], 현재값: 330
# 733번째 이웃상태: [30, 310, 320], 현재값: 330
# 734번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 735번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 736번째 이웃상태: [30, 310, 320], 현재값: 330
# 737번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 738번째 이웃상태: [30, 310, 320], 현재값: 330
# 739번째 이웃상태: [60, 330, 10, 20, 80, 90, 45, 130], 현재값: 30
# 740번째 이웃상태: [120, 70, 80, 140, 30, 105, 190], 현재값: 90
# 741번째 이웃상태: [100, 370, 90, 60, 120, 10, 85, 170], 현재값: 70
# 742번째 이웃상태: [90, 360, 80, 70, 110, 0, 75, 160], 현재값: 60
# 743번째 이웃상태: [190, 180, 170, 210, 100, 175, 60], 현재값: 160
# 744번째 이웃상태: [210, 160, 190, 230, 120, 195, 80], 현재값: 180
# 745번째 이웃상태: [225, 175, 205, 245, 135, 180, 95], 현재값: 195
# 746번째 이웃상태: [185, 195, 145, 190, 105], 현재값: 205
# 747번째 이웃상태: [170, 180, 130, 205, 90], 현재값: 190
# 748번째 이웃상태: [120, 70, 80, 140, 30, 105, 190], 현재값: 90
# 749번째 이웃상태: [135, 85, 95, 155, 45, 90, 205], 현재값: 105
# 750번째 이웃상태: [75, 25, 35, 95, 105, 30, 145], 현재값: 45
# 751번째 이웃상태: [45, 55, 65, 125, 135, 60], 현재값: 75
# 752번째 이웃상태: [105, 115, 125, 185, 75, 120], 현재값: 135
# 753번째 이웃상태: [45, 55, 65, 125, 135, 60], 현재값: 75
# 754번째 이웃상태: [105, 115, 125, 185, 75, 120], 현재값: 135
# 755번째 이웃상태: [135, 85, 95, 155, 45, 90, 205], 현재값: 105
# 756번째 이웃상태: [185, 195, 145, 190, 105], 현재값: 205
# 757번째 이웃상태: [125, 135, 205, 130, 45], 현재값: 145
# 758번째 이웃상태: [125, 135, 205, 130, 45], 현재값: 145
# 759번째 이웃상태: [160, 110, 120, 180, 190, 145, 30], 현재값: 130
# 760번째 이웃상태: [60, 330, 10, 20, 80, 90, 45, 130], 현재값: 30
# 761번째 이웃상태: [40, 310, 30, 0, 60, 70, 25, 110], 현재값: 10
# 762번째 이웃상태: [140, 130, 100, 160, 170, 125, 10], 현재값: 110
# 763번째 이웃상태: [190, 180, 150, 110, 220, 175, 60], 현재값: 160
# 764번째 이웃상태: [210, 170, 160, 235, 120], 현재값: 220
# 765번째 이웃상태: [150, 140, 110, 70, 60, 135, 220], 현재값: 120
# 766번째 이웃상태: [120, 170, 140, 100, 90, 165], 현재값: 150
# 767번째 이웃상태: [140, 150, 160, 120, 110, 185], 현재값: 170
# 768번째 이웃상태: [170, 120, 130, 90, 80, 155], 현재값: 140
# 769번째 이웃상태: [170, 120, 130, 90, 80, 155], 현재값: 140
# 770번째 이웃상태: [150, 140, 110, 70, 60, 135, 220], 현재값: 120
# 771번째 이웃상태: [120, 170, 140, 100, 90, 165], 현재값: 150
# 772번째 이웃상태: [60, 110, 80, 40, 150, 105, 190], 현재값: 90
# 773번째 이웃상태: [120, 170, 140, 100, 90, 165], 현재값: 150
# 774번째 이웃상태: [140, 150, 160, 120, 110, 185], 현재값: 170
# 775번째 이웃상태: [80, 90, 100, 60, 170, 125], 현재값: 110
# 776번째 이웃상태: [60, 110, 80, 40, 150, 105, 190], 현재값: 90
# 777번째 이웃상태: [10, 340, 60, 30, 90, 100, 55, 140], 현재값: 40
# 778번째 이웃상태: [25, 75, 45, 105, 115, 40, 155], 현재값: 55
# 779번째 이웃상태: [25, 75, 45, 105, 115, 40, 155], 현재값: 55
# 780번째 이웃상태: [55, 325, 45, 15, 75, 85, 10, 125], 현재값: 25
# 781번째 이웃상태: [75, 25, 35, 95, 105, 30, 145], 현재값: 45
# 782번째 이웃상태: [65, 335, 15, 45, 85, 95, 20, 135], 현재값: 35
# 783번째 이웃상태: [75, 25, 35, 95, 105, 30, 145], 현재값: 45
# 784번째 이웃상태: [125, 135, 205, 130, 45], 현재값: 145
# 785번째 이웃상태: [165, 115, 145, 185, 195, 120, 35], 현재값: 135
# 786번째 이웃상태: [135, 145, 225, 150, 65], 현재값: 165
# 787번째 이웃상태: [120, 130, 160, 200, 210, 165, 50], 현재값: 150
# 788번째 이웃상태: [20, 350, 30, 60, 100, 110, 65, 150], 현재값: 50
# 789번째 이웃상태: [35, 45, 75, 115, 125, 50, 165], 현재값: 65
# 790번째 이웃상태: [15, 345, 65, 55, 95, 105, 30, 145], 현재값: 45
# 791번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 792번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 793번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 794번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 795번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 796번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 797번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 798번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 799번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 800번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 801번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 802번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 803번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 804번째 이웃상태: [70, 360, 310, 385], 현재값: 370
# 805번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 806번째 이웃상태: [310, 40, 330], 현재값: 340
# 807번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 808번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 809번째 이웃상태: [310, 40, 330], 현재값: 340
# 810번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 811번째 이웃상태: [310, 40, 330], 현재값: 340
# 812번째 이웃상태: [310, 40, 330], 현재값: 340
# 813번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 814번째 이웃상태: [330, 0, 320, 310, 350, 360, 315, 400], 현재값: 300
# 815번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 816번째 이웃상태: [25, 315, 385, 310], 현재값: 325
# 817번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 818번째 이웃상태: [70, 360, 310, 385], 현재값: 370
# 819번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 820번째 이웃상태: [70, 360, 310, 385], 현재값: 370
# 821번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 822번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 823번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 824번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 825번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 826번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 827번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 828번째 이웃상태: [350, 20, 300, 330, 370, 380, 335], 현재값: 320
# 829번째 이웃상태: [70, 350, 320], 현재값: 370
# 830번째 이웃상태: [380, 50, 370, 360, 300, 410, 365], 현재값: 350
# 831번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 832번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 833번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 834번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 835번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 836번째 이웃상태: [35, 315, 395, 320], 현재값: 335
# 837번째 이웃상태: [35, 315, 395, 320], 현재값: 335
# 838번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 839번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 840번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 841번째 이웃상태: [345, 15, 335, 325, 365, 375, 300], 현재값: 315
# 842번째 이웃상태: [65, 315, 425, 350], 현재값: 365
# 843번째 이웃상태: [380, 50, 370, 360, 300, 410, 365], 현재값: 350
# 844번째 이웃상태: [380, 50, 370, 360, 300, 410, 365], 현재값: 350
# 845번째 이웃상태: [65, 315, 425, 350], 현재값: 365
# 846번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 847번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 848번째 이웃상태: [155, 425, 145, 135, 75, 65, 110, 225], 현재값: 125
# 849번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 850번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 851번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 852번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 853번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 854번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 855번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 856번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 857번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 858번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 859번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 860번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 861번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 862번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 863번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 864번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 865번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 866번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 867번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 868번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 869번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 870번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 871번째 이웃상태: [310, 40, 330], 현재값: 340
# 872번째 이웃상태: [340, 10, 330, 300, 360, 370, 325], 현재값: 310
# 873번째 이웃상태: [25, 315, 385, 310], 현재값: 325
# 874번째 이웃상태: [55, 325, 45, 15, 75, 85, 10, 125], 현재값: 25
# 875번째 이웃상태: [155, 145, 115, 175, 185, 110, 25], 현재값: 125
# 876번째 이웃상태: [125, 135, 205, 130, 45], 현재값: 145
# 877번째 이웃상태: [155, 145, 115, 175, 185, 110, 25], 현재값: 125
# 878번째 이웃상태: [215, 205, 175, 235, 125, 170, 85], 현재값: 185
# 879번째 이웃상태: [185, 195, 145, 190, 105], 현재값: 205
# 880번째 이웃상태: [185, 195, 145, 190, 105], 현재값: 205
# 881번째 이웃상태: [135, 85, 95, 155, 45, 90, 205], 현재값: 105
# 882번째 이웃상태: [120, 70, 80, 140, 30, 105, 190], 현재값: 90
# 883번째 이웃상태: [120, 70, 80, 140, 30, 105, 190], 현재값: 90
# 884번째 이웃상태: [170, 120, 130, 90, 80, 155], 현재값: 140
# 885번째 이웃상태: [110, 60, 70, 30, 140, 95, 180], 현재값: 80
# 886번째 이웃상태: [100, 370, 50, 80, 20, 130, 85, 170], 현재값: 70
# 887번째 이웃상태: [110, 60, 70, 30, 140, 95, 180], 현재값: 80
# 888번째 이웃상태: [80, 90, 100, 60, 170, 125], 현재값: 110
# 889번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 890번째 이웃상태: [130, 140, 150, 60], 현재값: 160
# 891번째 이웃상태: [120, 130, 160, 200, 210, 165, 50], 현재값: 150
# 892번째 이웃상태: [130, 140, 150, 60], 현재값: 160
# 893번째 이웃상태: [110, 160, 130, 190, 200, 155, 40], 현재값: 140
# 894번째 이웃상태: [130, 140, 150, 60], 현재값: 160
# 895번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 896번째 이웃상태: [10, 340, 60, 30, 90, 100, 55, 140], 현재값: 40
# 897번째 이웃상태: [25, 75, 45, 105, 115, 40, 155], 현재값: 55
# 898번째 이웃상태: [15, 345, 65, 55, 95, 105, 30, 145], 현재값: 45
# 899번째 이웃상태: [35, 45, 75, 115, 125, 50, 165], 현재값: 65
# 900번째 이웃상태: [20, 350, 30, 60, 100, 110, 65, 150], 현재값: 50
# 901번째 이웃상태: [50, 320, 0, 30, 70, 80, 35, 120], 현재값: 20
# 902번째 이웃상태: [60, 330, 10, 20, 80, 90, 45, 130], 현재값: 30
# 903번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 904번째 이웃상태: [30, 40, 50, 110, 120, 75, 160], 현재값: 60
# 905번째 이웃상태: [20, 350, 30, 60, 100, 110, 65, 150], 현재값: 50
# 906번째 이웃상태: [320, 50, 330], 현재값: 350
# 907번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 908번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 909번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 910번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 911번째 이웃상태: [300, 30, 350, 340, 380, 390, 345], 현재값: 330
# 912번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 913번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 914번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 915번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 916번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 917번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 918번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 919번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 920번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 921번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 922번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 923번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 924번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 925번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 926번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 927번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 928번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 929번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 930번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 931번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 932번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 933번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 934번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 935번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 936번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 937번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 938번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 939번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 940번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 941번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 942번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 943번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 944번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 945번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 946번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 947번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 948번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 949번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 950번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 951번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 952번째 이웃상태: [315, 45, 405, 330], 현재값: 345
# 953번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 954번째 이웃상태: [375, 105, 345, 390], 현재값: 405
# 955번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 956번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 957번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 958번째 이웃상태: [360, 90, 330, 405], 현재값: 390
# 959번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 960번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 961번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 962번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 963번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 964번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 965번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 966번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 967번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 968번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 969번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 970번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 971번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 972번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 973번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 974번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 975번째 이웃상태: [80, 360, 320, 395], 현재값: 380
# 976번째 이웃상태: [390, 60, 380, 370, 410, 300, 375], 현재값: 360
# 977번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 978번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 979번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 980번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 981번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 982번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 983번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 984번째 이웃상태: [95, 375, 335, 380], 현재값: 395
# 985번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 986번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 987번째 이웃상태: [85, 375, 325, 370], 현재값: 385
# 988번째 이웃상태: [405, 75, 395, 385, 425, 315, 360], 현재값: 375
# 989번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 990번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 991번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 992번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 993번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 994번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 995번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 996번째 이웃상태: [110, 360, 350, 425], 현재값: 410
# 997번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 998번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 999번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 1000번째 이웃상태: [125, 375, 365, 410], 현재값: 425
# 결과값: 425, 아이템 목록: [0, 1, 0, 0, 1, 1, 1, 0](=['노트북', '간식', '이어폰', '공책'])
